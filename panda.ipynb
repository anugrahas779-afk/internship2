# %%
import pandas as pd
data = {'Name':['Alice','Bob'],'Age':[25,30]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30]]
df = pd.DataFrame(lst,columns=['Name','Age'])
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
print(df)
df.head()
# Out:
#        Name  Age
# 0     Alice   25
# 1       Bob   30
# 2       Anu   35
# 3   Krishna   35
# 4      Hena   46
# 5  Parvathi   45
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2      Anu   35
# 3  Krishna   35
# 4     Hena   46

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30]]
df = pd.DataFrame(lst,columns=['Name','Age'])
print(df)
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
print(df)
df.tail()
# Out:
#        Name  Age
# 0     Alice   25
# 1       Bob   30
# 2       Anu   35
# 3   Krishna   35
# 4      Hena   46
# 5  Parvathi   45
#        Name  Age
# 1       Bob   30
# 2       Anu   35
# 3   Krishna   35
# 4      Hena   46
# 5  Parvathi   45

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
print(df)
df.info()
# Out:
#        Name  Age
# 0     Alice   25
# 1       Bob   30
# 2       Anu   35
# 3   Krishna   35
# 4      Hena   46
# 5  Parvathi   45
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      str
#  1   Age     6 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 228.0 bytes

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
print(df)
df.describe()
# Out:
#        Name  Age
# 0     Alice   25
# 1       Bob   30
# 2       Anu   35
# 3   Krishna   35
# 4      Hena   46
# 5  Parvathi   45
#              Age
# count   6.000000
# mean   36.000000
# std     8.246211
# min    25.000000
# 25%    31.250000
# 50%    35.000000
# 75%    42.500000
# max    46.000000

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
df['Name']
# Out:
# 0       Alice
# 1         Bob
# 2         Anu
# 3     Krishna
# 4        Hena
# 5    Parvathi
# Name: Name, dtype: str

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
df[['Name','Age']]
# Out:
#        Name  Age
# 0     Alice   25
# 1       Bob   30
# 2       Anu   35
# 3   Krishna   35
# 4      Hena   46
# 5  Parvathi   45

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
import pandas as pd
lst = [['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
import pandas as pd
lst = [['Jithu',18],['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
df[df['Age'] > 25]
# Out:
#        Name  Age
# 2       Bob   30
# 3       Anu   35
# 4   Krishna   35
# 5      Hena   46
# 6  Parvathi   45

# %%
import pandas as pd
lst = [['Jithu',18],['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
df['Gender']=['M','F','M','M','F','F','F']
df
# Out:
#        Name  Age Gender
# 0     Jithu   18      M
# 1     Alice   25      F
# 2       Bob   30      M
# 3       Anu   35      M
# 4   Krishna   35      F
# 5      Hena   46      F
# 6  Parvathi   45      F

# %%
import pandas as pd
lst = [['Jithu',18],['Alice',25],['Bob',30],['Anu',35],['Krishna',35],['Hena',46],['Parvathi',45]]
df = pd.DataFrame(lst,columns=['Name','Age'])
df['Gender']=['M','F','M','M','F','F','F']
df.drop('Age', axis=1, inplace=True)
df
# Out:
#        Name Gender
# 0     Jithu      M
# 1     Alice      F
# 2       Bob      M
# 3       Anu      M
# 4   Krishna      F
# 5      Hena      F
# 6  Parvathi      F

# %%
df.isnull()
# Out:
#     Name    Age  Gender
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False

# %%
df.dropna()
# Out:
#        Name  Age Gender
# 0     Jithu   18      M
# 1     Alice   25      F
# 2       Bob   30      M
# 3       Anu   35      M
# 4   Krishna   35      F
# 5      Hena   46      F
# 6  Parvathi   45      F

# %%
df.fillna(0)
# Out:
#        Name  Age Gender
# 0     Jithu   18      M
# 1     Alice   25      F
# 2       Bob   30      M
# 3       Anu   35      M
# 4   Krishna   35      F
# 5      Hena   46      F
# 6  Parvathi   45      F

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# F    37.750000
# M    27.666667
# Name: Age, dtype: float64

# %%
import pandas as pd
df1=pd.DataFrame({'key':[1,2,3],'Name':['Alice','Bob','Jithu']})
df2=pd.DataFrame({'key':[1,2,3],'Age':[25,30,18]})
pd.merge(df1, df2, on='key')
# Out:
#    key   Name  Age
# 0    1  Alice   25
# 1    2    Bob   30
# 2    3  Jithu   18

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Anu'],'Age': [25, 30, 21]}
df = pd.DataFrame(data)
df.to_csv('data.csv', index=False)
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 2    Anu   21

# %%
df.sort_values('Age')
# Out:
#     Name  Age
# 2    Anu   21
# 0  Alice   25
# 1    Bob   30

# %%
df.sort_values('Name')
# Out:
#     Name  Age
# 0  Alice   25
# 2    Anu   21
# 1    Bob   30

# %%
df['Age'].apply(lambda x: x + 1)
# Out:
# 0    26
# 1    31
# 2    22
# Name: Age, dtype: int64

# %%
df['Name'].unique()
# Out:
# <StringArray>
# ['Alice', 'Bob', 'Anu']
# Length: 3, dtype: str

# %%
import pandas as pd
data = {'Name': ['Alice', 'Anu', 'Anu'],'Age': [25, 30, 21]}
df = pd.DataFrame(data)
df.to_csv('data.csv', index=False)
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Anu   30
# 2    Anu   21

# %%
df['Name'].unique()
# Out:
# <StringArray>
# ['Alice', 'Anu']
# Length: 2, dtype: str

# %%
df['Age'].value_counts()
# Out:
# Age
# 25    1
# 30    1
# 21    1
# Name: count, dtype: int64

# %%
import pandas as pd
data = {'Name': ['Alice', 'Anu', 'Anu'],'Age': [21, 30, 21]}
df = pd.DataFrame(data)
df.to_csv('data.csv', index=False)
df
# Out:
#     Name  Age
# 0  Alice   21
# 1    Anu   30
# 2    Anu   21

# %%
df['Age'].value_counts()
# Out:
# Age
# 21    2
# 30    1
# Name: count, dtype: int64
